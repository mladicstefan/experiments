# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from typing import OrderedDict

# %%
x = torch.linspace(-1,1,100).reshape(100,1)
y = (x**2)

# %%
plt.plot(x,y)

# %%
model = nn.Sequential(
        (nn.Linear(1,16)),
        (nn.ReLU())
        (nn.Linear(16,16)),
        (nn.ReLU())
        (nn.Linear(16,1)),
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 model = nn.Sequential(
#       2         (nn.Linear(1,16)),
# ----> 3         (nn.ReLU())
#       4         (nn.Linear(16,16)),
#       5         (nn.ReLU())
#       6         (nn.Linear(16,1)),
#       7 )
#
# File ~/code/ml-litterbox/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/code/ml-litterbox/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/code/ml-litterbox/.venv/lib/python3.14/site-packages/torch/nn/modules/activation.py:143, in ReLU.forward(self, input)
#     139 def forward(self, input: Tensor) -> Tensor:
#     140     """
#     141     Runs the forward pass.
#     142     """
# --> 143     return F.relu(input, inplace=self.inplace)
#
# File ~/code/ml-litterbox/.venv/lib/python3.14/site-packages/torch/nn/functional.py:1721, in relu(input, inplace)
#    1719     result = torch.relu_(input)
#    1720 else:
# -> 1721     result = torch.relu(input)
#    1722 return result
#
# TypeError: relu(): argument 'input' (position 1) must be Tensor, not Linear
